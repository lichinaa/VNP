# %% [markdown]
# <ul><font size = 5 color='Orange'>
# Learning Goals</font>
# <font color = 'Orange'>
# <ul>We are using the same dataset as the previous laboratory exercise, now you need to build Neural networks</ul>
#
# <li>Build three different networks with using:</li>
# different layers, activation functions, neurans per layers, number of layers
# <li>train your network and set the optimal number of epochs and batch size</li>
# <li>Evaluate the three networks on the same test dataset</li>
# <li>Compare the results</li>
# </ul>

# %% [markdown]
# The Dataset for this exercise depends on your index number i.e number_of_data_set = index % 10:
#
#
# 0.  https://www.kaggle.com/tunguz/us-elections-dataset
# 1.  https://www.kaggle.com/andrewmvd/heart-failure-clinical-data
# 2.  https://www.kaggle.com/sootersaalu/amazon-top-50-bestselling-books-2009-2019
# 3.  https://www.kaggle.com/anmolkumar/health-insurance-cross-sell-prediction
# 4.  https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009
# 5.  https://www.kaggle.com/anmolkumar/house-price-prediction-challenge
# 6.  https://www.kaggle.com/datasets/tadhgfitzgerald/fifa-international-soccer-mens-ranking-1993now
# 7.  https://www.kaggle.com/arslanali4343/real-estate-dataset
# 8.  https://www.kaggle.com/terenceshin/covid19s-impact-on-airport-traffic
# 9.  https://www.kaggle.com/arslanali4343/top-personality-dataset

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Lab3_dataset/covid_impact_on_airport_traffic.csv')

# %%
data
# Out:
#      AggregationMethod        Date  Version                    AirportName  \
# 0                Daily  2020-04-03      1.0                Kingsford Smith
# 1                Daily  2020-04-13      1.0                Kingsford Smith
# 2                Daily  2020-07-10      1.0                Kingsford Smith
# 3                Daily  2020-09-02      1.0                Kingsford Smith
# 4                Daily  2020-10-31      1.0                Kingsford Smith
# ...                ...         ...      ...                            ...
# 7242             Daily  2020-06-05      1.0  Seattle-Tacoma International
# 7243             Daily  2020-10-03      1.0  Seattle-Tacoma International
# 7244             Daily  2020-07-16      1.0  Seattle-Tacoma International
# 7245             Daily  2020-07-31      1.0  Seattle-Tacoma International
# 7246             Daily  2020-08-30      1.0  Seattle-Tacoma International
#
# ...

# %%
data.isnull().sum()
# Out:
# AggregationMethod    0
# Date                 0
# Version              0
# AirportName          0
# PercentOfBaseline    0
# Centroid             0
# City                 0
# State                0
# ISO_3166_2           0
# Country              0
# Geography            0
# dtype: int64

# %%
data2=data.copy()

# %%
data2
# Out:
#      AggregationMethod        Date  Version                    AirportName  \
# 0                Daily  2020-04-03      1.0                Kingsford Smith
# 1                Daily  2020-04-13      1.0                Kingsford Smith
# 2                Daily  2020-07-10      1.0                Kingsford Smith
# 3                Daily  2020-09-02      1.0                Kingsford Smith
# 4                Daily  2020-10-31      1.0                Kingsford Smith
# ...                ...         ...      ...                            ...
# 7242             Daily  2020-06-05      1.0  Seattle-Tacoma International
# 7243             Daily  2020-10-03      1.0  Seattle-Tacoma International
# 7244             Daily  2020-07-16      1.0  Seattle-Tacoma International
# 7245             Daily  2020-07-31      1.0  Seattle-Tacoma International
# 7246             Daily  2020-08-30      1.0  Seattle-Tacoma International
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
data2['AirportName']= encoder.fit_transform(data2['AirportName'])

# %%
data2
# Out:
#      AggregationMethod        Date  Version  AirportName  PercentOfBaseline  \
# 0                Daily  2020-04-03      1.0           13                 64
# 1                Daily  2020-04-13      1.0           13                 29
# 2                Daily  2020-07-10      1.0           13                 54
# 3                Daily  2020-09-02      1.0           13                 18
# 4                Daily  2020-10-31      1.0           13                 22
# ...                ...         ...      ...          ...                ...
# 7242             Daily  2020-06-05      1.0           23                 80
# 7243             Daily  2020-10-03      1.0           23                 55
# 7244             Daily  2020-07-16      1.0           23                 76
# 7245             Daily  2020-07-31      1.0           23                 69
# 7246             Daily  2020-08-30      1.0           23                 68
#
# ...

# %%
df=data.copy()

# %%
df['AirportName'].unique()
# Out:
# array(['Kingsford Smith', 'Santiago International Airport',
#        'Calgary International', 'Edmonton International',
#        'Vancouver International', 'Winnipeg International',
#        'Halifax International', 'Toronto Pearson',
#        'Hamilton International', 'Montreal Mirabel', 'Montreal Trudeau',
#        'Los Angeles International', 'San Francisco International',
#        'Denver International', 'Miami International ',
#        'Hartsfield-Jackson Atlanta International ',
#        'Daniel K. Inouye International ', 'Chicago OHare International',
#        'Boston Logan International ',
#        'Detroit Metropolitan Wayne County ',
#        'Charlotte Douglas International', 'Newark Liberty International ',
#        'McCarran International', 'LaGuardia',
#        'John F. Kennedy International',
#        'Dallas/Fort Worth International ',
#        'Washington Dulles International ',
#        'Seattle-Tacoma International '], dtype=object)

# %%
listAirName = list(set(df['AirportName']))
listAirName
# Out:
# ['Montreal Mirabel',
#  'Charlotte Douglas International',
#  'Winnipeg International',
#  'Calgary International',
#  'Detroit Metropolitan Wayne County ',
#  'Chicago OHare International',
#  'Daniel K. Inouye International ',
#  'Hartsfield-Jackson Atlanta International ',
#  'LaGuardia',
#  'Halifax International',
#  'Los Angeles International',
#  'McCarran International',
#  'Washington Dulles International ',
#  'Dallas/Fort Worth International ',
#  'Newark Liberty International ',
#  'Edmonton International',
#  'Seattle-Tacoma International ',
#  'John F. Kennedy International',
#  'Toronto Pearson',
#  'Santiago International Airport',
#  'Miami International ',
#  'Kingsford Smith',
#  'Boston Logan International ',
#  'Vancouver International',
#  'Denver International',
#  'Montreal Trudeau',
#  'San Francisco International',
#  'Hamilton International']

# %%
dict={}
for i in range(0, len(listAirName)):
  dict[listAirName[i]]=i

dict
# Out:
# {'Montreal Mirabel': 0,
#  'Charlotte Douglas International': 1,
#  'Winnipeg International': 2,
#  'Calgary International': 3,
#  'Detroit Metropolitan Wayne County ': 4,
#  'Chicago OHare International': 5,
#  'Daniel K. Inouye International ': 6,
#  'Hartsfield-Jackson Atlanta International ': 7,
#  'LaGuardia': 8,
#  'Halifax International': 9,
#  'Los Angeles International': 10,
#  'McCarran International': 11,
#  'Washington Dulles International ': 12,
#  'Dallas/Fort Worth International ': 13,
#  'Newark Liberty International ': 14,
#  'Edmonton International': 15,
#  'Seattle-Tacoma International ': 16,
#  'John F. Kennedy International': 17,
#  'Toronto Pearson': 18,
#  'Santiago International Airport': 19,
#  'Miami International ': 20,
#  'Kingsford Smith': 21,
#  'Boston Logan International ': 22,
#  'Vancouver International': 23,
#  'Denver International': 24,
#  'Montreal Trudeau': 25,
#  'San Francisco International': 26,
#  'Hamilton International': 27}

# %%
df['AirportName']=[dict[df['AirportName'][i]] for i in range(0, len(df['AirportName']))]

# %%
df['AirportName']
# Out:
# 0       21
# 1       21
# 2       21
# 3       21
# 4       21
#         ..
# 7242    16
# 7243    16
# 7244    16
# 7245    16
# 7246    16
# Name: AirportName, Length: 7247, dtype: int64

# %%
df
# Out:
#      AggregationMethod        Date  Version  AirportName  PercentOfBaseline  \
# 0                Daily  2020-04-03      1.0           21                 64
# 1                Daily  2020-04-13      1.0           21                 29
# 2                Daily  2020-07-10      1.0           21                 54
# 3                Daily  2020-09-02      1.0           21                 18
# 4                Daily  2020-10-31      1.0           21                 22
# ...                ...         ...      ...          ...                ...
# 7242             Daily  2020-06-05      1.0           16                 80
# 7243             Daily  2020-10-03      1.0           16                 55
# 7244             Daily  2020-07-16      1.0           16                 76
# 7245             Daily  2020-07-31      1.0           16                 69
# 7246             Daily  2020-08-30      1.0           16                 68
#
# ...

# %%
df['Centroid'].unique()
# Out:
# array(['POINT(151.180087713813 -33.9459774986125)',
#        'POINT(-70.7942372739446 -33.3907265266744)',
#        'POINT(-114.013122872131 51.1184753727795)',
#        'POINT(-113.576260685047 53.308783097969)',
#        'POINT(-123.17754124324 49.1935788600694)',
#        'POINT(-97.2190621861971 49.9024712565967)',
#        'POINT(-63.5116720134583 44.8830168353507)',
#        'POINT(-79.6313443995196 43.679352363024)',
#        'POINT(-79.9266930701955 43.1720360844936)',
#        'POINT(-74.048379779338 45.6815027038316)',
#        'POINT(-73.7424121584688 45.4678436940192)',
#        'POINT(-118.404993180627 33.941369379328)',
#        'POINT(-122.38393507603 37.6211875471696)',
#        'POINT(-104.700315559089 39.8643468206413)',
#        'POINT(-80.2887147460152 25.7957243107604)',
#        'POINT(-84.4279188822754 33.6410758198944)',
#        'POINT(-157.918285204569 21.3259652488767)',
#        'POINT(-87.9105952039514 41.9804600429329)',
# ...

# %%
df['Centroid'].value_counts()
# Out:
# POINT(-84.4279188822754 33.6410758198944)     262
# POINT(-97.0394983968728 32.8940590356408)     262
# POINT(-73.7784465295804 40.6460265940045)     262
# POINT(-73.7424121584688 45.4678436940192)     262
# POINT(-118.404993180627 33.941369379328)      262
# POINT(-80.2887147460152 25.7957243107604)     261
# POINT(-77.4427728838621 38.9475939204352)     261
# POINT(-73.8732455278797 40.7738834966785)     261
# POINT(-115.14888081287 36.082853976328)       261
# POINT(-74.1751246689879 40.6915033838306)     261
# POINT(-80.9478114283204 35.2136892261228)     261
# POINT(-83.3537314720423 42.2129725988552)     261
# POINT(-71.0102909977065 42.3636330376787)     261
# POINT(-87.9105952039514 41.9804600429329)     261
# POINT(-157.918285204569 21.3259652488767)     261
# POINT(-122.308661576118 47.4505828917119)     261
# POINT(-104.700315559089 39.8643468206413)     261
# POINT(-122.38393507603 37.6211875471696)      261
# POINT(-79.6313443995196 43.679352363024)      261
# ...

# %%
list2 = list(set(df['Centroid']))

# %%
dict2={}
for i in range(0, len(list2)):
    dict2[list2[i]]=i
dict2
# Out:
# {'POINT(-84.4279188822754 33.6410758198944)': 0,
#  'POINT(-87.9105952039514 41.9804600429329)': 1,
#  'POINT(-115.14888081287 36.082853976328)': 2,
#  'POINT(-70.7942372739446 -33.3907265266744)': 3,
#  'POINT(-80.2887147460152 25.7957243107604)': 4,
#  'POINT(-118.404993180627 33.941369379328)': 5,
#  'POINT(-122.38393507603 37.6211875471696)': 6,
#  'POINT(-83.3537314720423 42.2129725988552)': 7,
#  'POINT(-73.7784465295804 40.6460265940045)': 8,
#  'POINT(-63.5116720134583 44.8830168353507)': 9,
#  'POINT(-79.9266930701955 43.1720360844936)': 10,
#  'POINT(-122.308661576118 47.4505828917119)': 11,
#  'POINT(-80.9478114283204 35.2136892261228)': 12,
#  'POINT(-79.6313443995196 43.679352363024)': 13,
#  'POINT(-104.700315559089 39.8643468206413)': 14,
#  'POINT(-74.1751246689879 40.6915033838306)': 15,
#  'POINT(-157.918285204569 21.3259652488767)': 16,
#  'POINT(-114.013122872131 51.1184753727795)': 17,
#  'POINT(-123.17754124324 49.1935788600694)': 18,
# ...

# %%
df['Centroid']= [dict2[df['Centroid'][i]] for i in range(0, len(df['Centroid']))]

# %%
df['Centroid']
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 7242    11
# 7243    11
# 7244    11
# 7245    11
# 7246    11
# Name: Centroid, Length: 7247, dtype: int64

# %%
df
# Out:
#      AggregationMethod        Date  Version  AirportName  PercentOfBaseline  \
# 0                Daily  2020-04-03      1.0           21                 64
# 1                Daily  2020-04-13      1.0           21                 29
# 2                Daily  2020-07-10      1.0           21                 54
# 3                Daily  2020-09-02      1.0           21                 18
# 4                Daily  2020-10-31      1.0           21                 22
# ...                ...         ...      ...          ...                ...
# 7242             Daily  2020-06-05      1.0           16                 80
# 7243             Daily  2020-10-03      1.0           16                 55
# 7244             Daily  2020-07-16      1.0           16                 76
# 7245             Daily  2020-07-31      1.0           16                 69
# 7246             Daily  2020-08-30      1.0           16                 68
#
#       Centroid    City            State ISO_3166_2  \
# ...

# %%
df['City'].unique()
# Out:
# array(['Sydney', 'Santiago', 'Calgary', 'Leduc County', 'Richmond',
#        'Winnipeg', 'Halifax', 'Mississauga', 'Hamilton', 'Mirabel',
#        'Dorval', 'Los Angeles', 'South San Francisco', 'Denver',
#        'Miami Springs', 'College Park', 'Urban Honolulu', 'Chicago',
#        'Boston', 'Romulus', 'Charlotte', 'Newark', 'Paradise', 'New York',
#        'Grapevine', 'Floris', 'SeaTac'], dtype=object)

# %%
list3= list(set(df['City']))
list3
# Out:
# ['Halifax',
#  'Santiago',
#  'College Park',
#  'Los Angeles',
#  'Richmond',
#  'SeaTac',
#  'Leduc County',
#  'Denver',
#  'Urban Honolulu',
#  'New York',
#  'Mississauga',
#  'Miami Springs',
#  'Calgary',
#  'Sydney',
#  'South San Francisco',
#  'Romulus',
#  'Mirabel',
#  'Charlotte',
#  'Grapevine',
#  'Floris',
#  'Boston',
#  'Newark',
#  'Winnipeg',
#  'Paradise',
#  'Chicago',
#  'Hamilton',
#  'Dorval']

# %%
dict4={}
for i in range(0, len(list3)):
  dict4[list3[i]]=i

dict4
# Out:
# {'Halifax': 0,
#  'Santiago': 1,
#  'College Park': 2,
#  'Los Angeles': 3,
#  'Richmond': 4,
#  'SeaTac': 5,
#  'Leduc County': 6,
#  'Denver': 7,
#  'Urban Honolulu': 8,
#  'New York': 9,
#  'Mississauga': 10,
#  'Miami Springs': 11,
#  'Calgary': 12,
#  'Sydney': 13,
#  'South San Francisco': 14,
#  'Romulus': 15,
#  'Mirabel': 16,
#  'Charlotte': 17,
#  'Grapevine': 18,
#  'Floris': 19,
#  'Boston': 20,
#  'Newark': 21,
#  'Winnipeg': 22,
#  'Paradise': 23,
#  'Chicago': 24,
#  'Hamilton': 25,
#  'Dorval': 26}

# %%
df['City'] = [dict4[df['City'][i]] for i in range(0, len(df['City']))]

# %%
df['City'].unique()
# Out:
# array([13,  1, 12,  6,  4, 22,  0, 10, 25, 16, 26,  3, 14,  7, 11,  2,  8,
#        24, 20, 15, 17, 21, 23,  9, 18, 19,  5])

# %%
df
# Out:
#      AggregationMethod        Date  Version  AirportName  PercentOfBaseline  \
# 0                Daily  2020-04-03      1.0           21                 64
# 1                Daily  2020-04-13      1.0           21                 29
# 2                Daily  2020-07-10      1.0           21                 54
# 3                Daily  2020-09-02      1.0           21                 18
# 4                Daily  2020-10-31      1.0           21                 22
# ...                ...         ...      ...          ...                ...
# 7242             Daily  2020-06-05      1.0           16                 80
# 7243             Daily  2020-10-03      1.0           16                 55
# 7244             Daily  2020-07-16      1.0           16                 76
# 7245             Daily  2020-07-31      1.0           16                 69
# 7246             Daily  2020-08-30      1.0           16                 68
#
#       Centroid  City            State ISO_3166_2  \
# ...

# %%
df.drop(['State'], inplace=True, axis=1)

# %%
df.drop(['Country'], inplace=True, axis=1)

# %%
df.drop(['Geography'], inplace=True, axis=1)

# %%
df.drop(['ISO_3166_2'], inplace=True, axis=1)

# %%
df.drop('AggregationMethod', inplace=True, axis=1)

# %%
df.drop('Version', inplace=True, axis=1)

# %%
df
# Out:
#             Date  AirportName  PercentOfBaseline  Centroid  City
# 0     2020-04-03           21                 64        20    13
# 1     2020-04-13           21                 29        20    13
# 2     2020-07-10           21                 54        20    13
# 3     2020-09-02           21                 18        20    13
# 4     2020-10-31           21                 22        20    13
# ...          ...          ...                ...       ...   ...
# 7242  2020-06-05           16                 80        11     5
# 7243  2020-10-03           16                 55        11     5
# 7244  2020-07-16           16                 76        11     5
# 7245  2020-07-31           16                 69        11     5
# 7246  2020-08-30           16                 68        11     5
#
# [7247 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date                 object
# AirportName           int64
# PercentOfBaseline     int64
# Centroid              int64
# City                  int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7247 entries, 0 to 7246
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               7247 non-null   object
#  1   AirportName        7247 non-null   int64
#  2   PercentOfBaseline  7247 non-null   int64
#  3   Centroid           7247 non-null   int64
#  4   City               7247 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 283.2+ KB

# %%
df['Date'].value_counts()
# Out:
# 2020-04-03    28
# 2020-11-27    28
# 2020-10-16    28
# 2020-05-15    28
# 2020-09-28    28
#               ..
# 2020-03-29    26
# 2020-08-16    26
# 2020-04-05    25
# 2020-04-19    24
# 2020-08-17     5
# Name: Date, Length: 262, dtype: int64

# %%
list5= list(set(df['Date']))

# %%
pom={}
for i in range(0, len(list5)):
  pom[list5[i]]=i

pom
# Out:
# {'2020-11-04': 0,
#  '2020-10-19': 1,
#  '2020-06-18': 2,
#  '2020-09-29': 3,
#  '2020-07-18': 4,
#  '2020-09-13': 5,
#  '2020-09-22': 6,
#  '2020-06-25': 7,
#  '2020-07-03': 8,
#  '2020-07-29': 9,
#  '2020-03-19': 10,
#  '2020-11-19': 11,
#  '2020-10-15': 12,
#  '2020-09-04': 13,
#  '2020-05-24': 14,
#  '2020-07-13': 15,
#  '2020-06-05': 16,
#  '2020-11-06': 17,
#  '2020-12-02': 18,
#  '2020-06-12': 19,
#  '2020-10-17': 20,
#  '2020-08-17': 21,
#  '2020-10-30': 22,
#  '2020-08-06': 23,
#  '2020-11-24': 24,
#  '2020-08-14': 25,
#  '2020-03-30': 26,
#  '2020-06-19': 27,
#  '2020-04-23': 28,
#  '2020-09-26': 29,
#  '2020-10-23': 30,
#  '2020-06-08': 31,
#  '2020-05-22': 32,
#  '2020-09-09': 33,
#  '2020-08-23': 34,
#  '2020-10-24': 35,
#  '2020-11-18': 36,
#  '2020-05-15': 37,
#  '2020-07-16': 38,
#  '2020-03-27': 39,
#  '2020-07-09': 40,
#  '2020-05-19': 41,
#  '2020-08-27': 42,
#  '2020-05-23': 43,
#  '2020-07-21': 44,
#  '2020-05-13': 45,
#  '2020-07-28': 46,
#  '2020-11-23': 47,
# ...

# %%
df['Date']=[pom[df['Date'][i]] for i in range(0, len(df['Date'])) ]

# %%
df['Date']
# Out:
# 0       175
# 1       217
# 2       195
# 3       191
# 4        70
#        ...
# 7242     16
# 7243    183
# 7244     38
# 7245    226
# 7246    114
# Name: Date, Length: 7247, dtype: int64

# %%
df
# Out:
#       Date  AirportName  PercentOfBaseline  Centroid  City
# 0      175           21                 64        20    13
# 1      217           21                 29        20    13
# 2      195           21                 54        20    13
# 3      191           21                 18        20    13
# 4       70           21                 22        20    13
# ...    ...          ...                ...       ...   ...
# 7242    16           16                 80        11     5
# 7243   183           16                 55        11     5
# 7244    38           16                 76        11     5
# 7245   226           16                 69        11     5
# 7246   114           16                 68        11     5
#
# [7247 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot=True,cmap='hsv',fmt='.3f',linewidths=2)
plt.show()

# %%
df2= df.copy()

# %%
X= df2.drop('PercentOfBaseline', axis=1)
Y=df2['PercentOfBaseline']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
X_train
# Out:
#       Date  AirportName  Centroid  City
# 6673   105           13        24    18
# 2331   145            0        19    16
# 812    237           15        25     6
# 2380   213            0        19    16
# 497    255            3        17    12
# ...    ...          ...       ...   ...
# 2290   183            0        19    16
# 5443    88           14        15    21
# 2711   214           25        26    26
# 7177    43           16        11     5
# 5530   227           14        15    21
#
# [5797 rows x 4 columns]

# %%
Y_test
# Out:
# 4578    81
# 1168    91
# 2901    79
# 474     24
# 1121    66
#         ..
# 6765    65
# 6693    73
# 5193    90
# 2666    86
# 620     65
# Name: PercentOfBaseline, Length: 1450, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
Y_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.34128756, -0.04865873,  1.30379402,  0.66356306],
#        [ 0.18821784, -1.65768487,  0.68299582,  0.40253262],
#        [ 1.40608028,  0.19888375,  1.42795366, -0.90261957],
#        ...,
#        [ 1.10161467,  1.43659617,  1.5521133 ,  1.70768481],
#        [-1.16202095,  0.32265499, -0.3102813 , -1.03313479],
#        [ 1.27370393,  0.07511251,  0.18635726,  1.05510871]])

# %%
Y_test
# Out:
# array([[-0.02358432, -1.03882866, -1.5518777 ,  1.44665437],
#        [-0.28833702,  1.18905368,  0.55883618, -1.16365001],
#        [ 0.57210927, -0.41997245, -1.05523914, -1.29416522],
#        ...,
#        [-1.58562527, -1.53391363, -0.18612166,  0.53304784],
#        [ 0.12202967,  1.43659617,  1.5521133 ,  1.70768481],
#        [-0.1294854 , -1.28637115,  0.43467654, -0.11952826]])

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# %%
len(X_train[0])
# Out:
# 4

# %%
model.add(Dense(32, input_dim=4, activation='relu'))

# %%
model.add(Dense(16, activation='relu'))

# %%
model.add(Dense(16, activation='relu'))

# %%
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                160
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 16)                272
#
#  dense_3 (Dense)             (None, 1)                 17
#
# ...
# Total params: 977
# Trainable params: 977
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')

# %%
history = model.fit(X_train, Y_train, epochs=30, batch_size=10, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/30
# 464/464 [==============================] - 2s 3ms/step - loss: 2040.7272 - val_loss: 461.0438
# Epoch 2/30
# 464/464 [==============================] - 1s 2ms/step - loss: 442.1825 - val_loss: 423.7035
# Epoch 3/30
# 464/464 [==============================] - 1s 2ms/step - loss: 417.6741 - val_loss: 405.8485
# Epoch 4/30
# 464/464 [==============================] - 1s 2ms/step - loss: 400.0905 - val_loss: 387.9601
# Epoch 5/30
# 464/464 [==============================] - 1s 2ms/step - loss: 379.7214 - val_loss: 363.9694
# Epoch 6/30
# 464/464 [==============================] - 1s 2ms/step - loss: 359.2506 - val_loss: 347.3435
# Epoch 7/30
# 464/464 [==============================] - 1s 2ms/step - loss: 339.0169 - val_loss: 327.1402
# Epoch 8/30
# 464/464 [==============================] - 1s 2ms/step - loss: 323.2557 - val_loss: 309.4922
# Epoch 9/30
# 464/464 [==============================] - 1s 2ms/step - loss: 309.1782 - val_loss: 296.1641
# Epoch 10/30
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'validation'])

# %%
y_pred = model.predict(X_test)
# Out:
# 46/46 [==============================] - 0s 1ms/step

# %%
plt.plot(Y_test, color = 'green')
plt.plot(y_pred, color = 'blue')

# %%
from sklearn.metrics import r2_score

# %%
df3= df.copy()

# %%
X= df3.drop('PercentOfBaseline', axis=1)
Y=df3['PercentOfBaseline']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train = sc.fit_transform(X_train)
Y_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(32, input_dim=4, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='linear'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 32)                160
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dense_6 (Dense)             (None, 16)                272
#
#  dense_7 (Dense)             (None, 1)                 17
#
# ...
# Total params: 977
# Trainable params: 977
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')

# %%
history = model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/10
# 145/145 [==============================] - 1s 4ms/step - loss: 4390.4009 - val_loss: 2473.8586
# Epoch 2/10
# 145/145 [==============================] - 0s 3ms/step - loss: 860.3904 - val_loss: 474.8806
# Epoch 3/10
# 145/145 [==============================] - 0s 3ms/step - loss: 468.5222 - val_loss: 437.2269
# Epoch 4/10
# 145/145 [==============================] - 0s 3ms/step - loss: 441.5840 - val_loss: 419.3514
# Epoch 5/10
# 145/145 [==============================] - 0s 2ms/step - loss: 426.2937 - val_loss: 409.3990
# Epoch 6/10
# 145/145 [==============================] - 0s 2ms/step - loss: 415.6397 - val_loss: 391.6256
# Epoch 7/10
# 145/145 [==============================] - 0s 3ms/step - loss: 404.5337 - val_loss: 383.0059
# Epoch 8/10
# 145/145 [==============================] - 0s 3ms/step - loss: 395.0582 - val_loss: 381.7799
# Epoch 9/10
# 145/145 [==============================] - 0s 3ms/step - loss: 386.8924 - val_loss: 364.2436
# Epoch 10/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'validation'])

# %%
y_pred2 = model.predict(X_test)
# Out:
# 46/46 [==============================] - 0s 1ms/step

# %%
plt.plot(Y_test, color = 'green')
plt.plot(y_pred, color = 'blue')

# %%
df4=df.copy()

# %%
X= df4.drop('PercentOfBaseline', axis=1)
Y=df4['PercentOfBaseline']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train = sc.fit_transform(X_train)
Y_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(32, input_dim=4, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 32)                160
#
#  dense_9 (Dense)             (None, 16)                528
#
#  dense_10 (Dense)            (None, 16)                272
#
#  dense_11 (Dense)            (None, 1)                 17
#
# ...
# Total params: 977
# Trainable params: 977
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')

# %%
history = model.fit(X_train, Y_train, epochs=10, batch_size=64, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/10
# 73/73 [==============================] - 1s 9ms/step - loss: 4815.5747 - val_loss: 4865.5244
# Epoch 2/10
# 73/73 [==============================] - 0s 3ms/step - loss: 4774.8584 - val_loss: 4857.0713
# Epoch 3/10
# 73/73 [==============================] - 0s 3ms/step - loss: 4772.7383 - val_loss: 4856.7168
# Epoch 4/10
# 73/73 [==============================] - 0s 3ms/step - loss: 4772.5420 - val_loss: 4856.6206
# Epoch 5/10
# 73/73 [==============================] - 0s 3ms/step - loss: 4772.4751 - val_loss: 4856.5806
# Epoch 6/10
# 73/73 [==============================] - 0s 3ms/step - loss: 4772.4468 - val_loss: 4856.5605
# Epoch 7/10
# 73/73 [==============================] - 0s 2ms/step - loss: 4772.4307 - val_loss: 4856.5493
# Epoch 8/10
# 73/73 [==============================] - 0s 3ms/step - loss: 4772.4209 - val_loss: 4856.5415
# Epoch 9/10
# 73/73 [==============================] - 0s 2ms/step - loss: 4772.4146 - val_loss: 4856.5361
# Epoch 10/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'validation'])

# %%
y_pred3 = model.predict(X_test)
# Out:
# 46/46 [==============================] - 0s 2ms/step

# %%
plt.plot(Y_test, color = 'green')
plt.plot(y_pred, color = 'blue')
